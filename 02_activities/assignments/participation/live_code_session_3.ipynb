# %%
# import libraries

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import PIL
import requests

# %%
# sample data

np.random.seed(613)
x = np.arange(50)
y1 = np.random.randint(0,100,50)
y2 = np.random.randint(0,100,50)

# %%
# draw a line plot with both y variables on the same axes
fig, ax = plt.subplots(figsize=(5,3)) 
ax.plot(x,y1)
ax.plot(x,y2)

# %%
# now to add a legend
# we have to add a label to each line plot

fig, ax = plt.subplots(figsize=(5,3))
ax.plot(x,y1, label = 'Person 1')
ax.plot(x,y2, label = 'Person 2')
ax.legend(loc = 'lower right')
# fig.show() # we don't need it in VS code, but might be necessary on a different platform

# %%
# customizing the legend

fig, ax = plt.subplots(figsize=(5,3))
ax.plot(x, y1, label = 'Person 1')
ax.plot(x, y2, label = 'Person 2')
ax.legend(loc = 'lower right',
          frameon = True, # adds a frame around the legend
          fontsize = 12, # sets the font size
          ncol = 2, # specifies the number of columns
          shadow = True)

# %%
# moving the legend outside the plot

fig, ax = plt.subplots(figsize=(5,3))
ax.plot(x,y1, label='Person 1')
ax.plot(x, y2, label = 'Person 2')
ax.legend(loc = 'upper left',
          bbox_to_anchor = (1,1)) 
# bbox_to_anchor(i,j) location of the loc of the legend (upper left corner of the legend will be moved 100*i% on the x-axis and 100*j% on the y-axis)

# %%
fig, ax = plt.subplots(figsize=(5,3))
ax.plot(x,y1, label='Person 1')
ax.plot(x, y2, label = 'Person 2')
ax.legend(loc = 'upper left',
          bbox_to_anchor = (0.5,0.5))

# %%
# Adding annotationas

fig, ax = plt.subplots(figsize=(5,3))
ax.scatter(x,y1, label = 'Person 1')
ax.scatter(x,y2, label = 'Person 2')
ax.legend(loc = 'lower right')
ax.text(10,95,'This value is important!') #adds text starting location x=10, y=95
# Out:
# Text(10, 95, 'This value is important!')

# %%
# we can modify text annotations by adding arguments
fig, ax = plt.subplots(figsize=(5,3))
ax.scatter(x,y1, label = 'Person 1')
ax.scatter(x,y2, label = 'Person 2')
ax.legend(loc = 'lower right')
ax.text(10,95,'This value is important!', 
        ha = 'center', #horizontal alignment of text (so the center of our text will be at location x=10, y=95)
        color = 'red', # modify font color
        size = 20) # modify font size
# Out:
# Text(10, 95, 'This value is important!')

# %%
# we can position text by linking it to a specific point using transforms

# we'll start by making a simple empty set of axes

fig, ax = plt.subplots()
ax.axis([0, 10, 0, 10]) 

ax.text(1,5, ". Data:(1,5)", transform = ax.transData)
ax.text(0.5, 0.1, ". Axes:(0.5, 0.1)", transform = ax.transAxes) # location is specified as a percentage of axes 
ax.text(0.2, 0.2, ". Figure:(0.2,0.2)", transform = fig.transFigure) 
# location is specified as a percentage of the figure, which is the whole big box
# Out:
# Text(0.2, 0.2, '. Figure:(0.2,0.2)')

# %%
# Annotating with arrows

fig, ax = plt.subplots(figsize=(5,3))
ax.scatter(x,y1, label = 'Person 1')
ax.scatter(x,y2, label = 'Person 2')
ax.legend(loc = 'lower right')

ax.annotate('This is important!', 
            xy=(10,95), # where we want the arrow to go
            xytext =(20,94), # where we want the arrow to go
            arrowprops=dict(facecolor = 'black', shrink=0.05)) 
            # shrink moves the tip and base of the arrow 5% away from the annotated point/text
# Out:
# Text(20, 94, 'This is important!')

# %%
fig, ax = plt.subplots(figsize=(5,3))
ax.scatter(x,y1, label = 'Person 1')
ax.scatter(x,y2, label = 'Person 2')
ax.legend(loc = 'lower right')

ax.annotate('This is important!', 
            xy=(10,95), # where we want the arrow to go
            xytext =(20,94), # where we want the arrow to go
            arrowprops=dict(arrowstyle = 'wedge', color = 'hotpink'))
# Out:
# Text(20, 94, 'This is important!')

# %%
# how to remove tick marks or labels from our axes


fig, ax = plt.subplots(figsize=(5,3))
ax.scatter(x,y1, label = 'Person 1')
ax.scatter(x,y2, label = 'Person 2')
ax.legend(loc = 'lower right')

ax.yaxis.set_major_locator(plt.NullLocator()) # removes ticks and labels on the y axis
ax.xaxis.set_major_formatter(plt.NullFormatter()) # removes the labels on the x-axis but not the ticks

# %%
# defining a maximum number of ticks on our axis


fig, ax = plt.subplots(figsize=(5,3))
ax.scatter(x,y1, label = 'Person 1')
ax.scatter(x,y2, label = 'Person 2')
ax.legend(loc = 'lower right')

ax.xaxis.set_major_locator(plt.MaxNLocator(3)) # only 3 ticks/labels on the x axis

# %%
# Set ticks at a specific interval

fig, ax = plt.subplots(figsize=(5,3))
ax.scatter(x,y1, label = 'Person 1')
ax.scatter(x,y2, label = 'Person 2')
ax.legend(loc = 'lower right')

ax.xaxis.set_major_locator(plt.MultipleLocator(5)) # a tick every 5 points on the x-axis

# %%
# to rotate axis labels and horizontal alignment


fig, ax = plt.subplots(figsize=(5,3))
ax.scatter(x,y1, label = 'Person 1')
ax.scatter(x,y2, label = 'Person 2')
ax.legend(loc = 'lower right')

plt.xticks(rotation = 45, ha = 'right') # labels will be rotated by 45 degrees
# Out:
# (array([-10.,   0.,  10.,  20.,  30.,  40.,  50.,  60.]),
#  [Text(-10.0, 0, '−10'),
#   Text(0.0, 0, '0'),
#   Text(10.0, 0, '10'),
#   Text(20.0, 0, '20'),
#   Text(30.0, 0, '30'),
#   Text(40.0, 0, '40'),
#   Text(50.0, 0, '50'),
#   Text(60.0, 0, '60')])

# %%
# Activity - x axis title should be serif font, indigo color, with title "Shiny New x Axis" - use plt.xlabel()

# step 1: define our font
font1 = {'family': 'serif', 'color':'indigo', 'size':12}

fig, ax = plt.subplots(figsize=(5,3))
ax.scatter(x,y1, label = 'Person 1')
ax.scatter(x,y2, label = 'Person 2')
ax.legend(loc = 'lower right')

plt.xlabel('Shiny New x Axis', fontdict=font1)
# Out:
# Text(0.5, 0, 'Shiny New x Axis')

# %%
# styles have a sort of saved configuration for our plots
# to view available styles
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
# to use one of these styles, we add the following line of code before making our figure
# plt.style.use('style_name')

plt.style.use('fivethirtyeight')
#plt.style.use('seaborn-v0_8-colorblind')

fig, ax = plt.subplots(figsize=(5,3))
ax.scatter(x,y1, label = 'Person 1')
ax.scatter(x,y2, label = 'Person 2')
ax.legend(loc = 'lower right')
